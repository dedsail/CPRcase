# %%
import numpy #massive
import pandas #table
import matplotlib #visuale
import seaborn as sns #graphic analize
from sklearn import datasets #ml
from sklearn.model_selection import train_test_split #ml test model
import requests #zaprosi http
from flask import Flask #website
import django #website helper
import cv2 #ml eye
import nltk #lang
import sympy #symb math
from PIL import Image #image
import json #json file read
import csv #csv file read
import os #system
import math #math
from matplotlib import pyplot as plt #vis

# %%
plt.plot([1,2,3],[4,5,6])
plt.show()
